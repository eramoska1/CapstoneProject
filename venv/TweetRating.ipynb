# %%
# Evelina Ramoskaite
import pandas as pd
import csv
# Tweet Rating Code
fileName= input('FileName:')
stock= input('hashtag ticker for file:')
data = pd.read_csv(fileName)
print('There are {} records in this dataset.'.format(len(data)))
print('to quit, type quit.')
# Decoding the text columns
import ast
data.tweet_text = data['tweet_text'].apply(ast.literal_eval).str.decode("utf-8")
data[' username']= data[' username'].apply(ast.literal_eval).str.decode("utf-8")

ratings = []
for i in data.tweet_text:
    count= 0
    print(i)
    rating = input('Rate(0/1/2):')
    ratings.append(rating)
    count += 1
    if count//50:
        print('count: {} , total left: {}'.format(count,len(data)-count))
    if rating == 'quit':
        dict = {'rating': ratings}
        ratingData = pd.DataFrame(dict)
        ratingData.to_csv('rated_{}_inc.csv'.format(stock))
        break
data['target'] =ratings
data.target
data.to_csv('rated_{}.csv'.format(stock))
# Out:
# FileName:hastagBTC-USD.csv
# hashtag ticker for file:btc
# There are 47121 records in this dataset.
# to quit, type quit.
# This is finally rising to the surface!!  On why bitcoin not altcoin—-&gt; https://t.co/qwdJScENKX
# Rate(0/1/2):0
# #Investing 43.8% in this optimal #crypto portfolio and 56.2% #cash in the past 24 hours would have given you a 3.0% return rather than #Bitcoin's -0.4%, for the same level of #risk https://t.co/YOcDAnPJE9
# Rate(0/1/2):1
# Crypto Currency Whale Makes M Bitcoin Wager on Kentucky Derby - Fintech Southeast https://t.co/9ciVDcOcM6
# Rate(0/1/2):10
# @RealisticCrypt1 Bitcoin hits $63k. Take this chance to mine and accelerate your coins I grow btc weekly, you can hit me up for $3000 minimum profit #Binance #bitcoin #Bitcoin #Btc #invest #trade
# Rate(0/1/2):0
# @spectatorindex Can some expert of crypto currency tell me why a bitcoin (a crypto currency) is worth 54k USD but a dogecoin (a crypto currency) cost only 0.32$? Why? Should all crypto currency not be an equal worth? pardon me for zero knowledge but i genuinely want to know this currency system.
# Rate(0/1/2):0
# @bitfalls why would you call bitcoin an altcoin when the term itself means alternate coins (which are not bitcoin)
# Rate(0/1/2):0
# @brant_vogt @RyanLEllis @JoeBiden I really hope you are right about bitcoin.
# Rate(0/1/2):0
# @Prodigy_PUBG @RemindMe_OfThis Hi plz help me plz  I'm Nurse . We fight for corona virus Plz send Crypto   Bitcoin :   bc1q0r3ps99ltvn654d5w445ssygm5frwvsgcy7g73  TRON :   TXHi75oy4GEXnMFYEKL4p1pwGGCv5nEvCf  Etherium :   0xd1Dcb986cFE1b71fEd89e91aF2b7771dfadddF17
# Rate(0/1/2):quit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-fdf04cfa75ff> in <module>
#      23         print('count: {} , total left: {}'.format(count,len(data)-count))
#      24     if rating == 'quit':
# ---> 25         data['target'] = ratings
#      26         data.to_csv('rated_{}.csv'.format(stock))
#      27         break
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3762
#    3763             # turn me into an ndarray
# -> 3764             value = sanitize_index(value, self.index)
#    3765             if not isinstance(value, (np.ndarray, Index)):
#    3766                 if isinstance(value, list) and len(value) > 0:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     745     """
#     746     if len(data) != len(index):
# --> 747         raise ValueError(
#     748             "Length of values "
#     749             f"({len(data)}) "
#
# ValueError: Length of values (8) does not match length of index (47121)

# %%
data.head(5)
# Out:
#              timestamp                                         tweet_text  \
# 0  2021-04-28 23:59:58  This is finally rising to the surface!!  On wh...
# 1  2021-04-28 23:59:57  #Investing 43.8% in this optimal #crypto portf...
# 2  2021-04-28 23:59:55  Crypto Currency Whale Makes M Bitcoin Wager on...
# 3  2021-04-28 23:59:55  @RealisticCrypt1 Bitcoin hits $63k. Take this ...
# 4  2021-04-28 23:59:55  @spectatorindex Can some expert of crypto curr...
#
#                                         all_hashtags  retweet_count  \
# 0                                                 []              2
# 1  ['Investing', 'crypto', 'cash', 'Bitcoin', 'ri...              0
# 2                                                 []              0
# 3  ['Binance', 'bitcoin', 'Bitcoin', 'Btc', 'inve...              0
# 4                                                 []              1
#
#       tweet_created_at        username  followers_count
# 0  2021-04-28 23:59:58  AwyeeDeaterBob             3638
# 1  2021-04-28 23:59:57  CryptoWatchBot             2037
# 2  2021-04-28 23:59:55       FintechSE              205
# 3  2021-04-28 23:59:55       buren_tom               34
# 4  2021-04-28 23:59:55  AbabeelTheBird              181
